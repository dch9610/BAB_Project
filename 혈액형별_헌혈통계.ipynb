# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
import datetime
import seaborn as sns
# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# %%
blood = pd.read_csv('blood data/혈액형별_헌혈통계_2005_2019.csv', encoding = 'cp949')
blood
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)     2005   2005.1   2005.2  2005.3   2005.4  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 1    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 2    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 3         합계       소계      계  2274336  2265832     99.6  620195     27.3
# 4         합계       소계      남  1831613  1825105     99.6  498226     27.2
# 5         합계       소계      여   442723   440727     99.5  121969     27.5
# 6     대한적십자사       소계      계  2223636  2215240     99.6  606013     27.3
# 7     대한적십자사       소계      남  1789525  1783096     99.6  486553     27.2
# 8     대한적십자사       소계      여   434111   432144     99.5  119460     27.5
# 9     대한적십자사     서울중앙      계   210606   209810     99.6   56961     27.0
# 10    대한적십자사     서울중앙      남   169824   169215     99.6   45967     27.1
# 11    대한적십자사     서울중앙      여    40782    40595     99.5   10994     27.0
# ...

# %%
blood_Co =blood.copy()

# %%
blood_Co.drop(columns=['혈액원별(1)'])
# Out:
#     혈액원별(2)  성별(1)     2005   2005.1   2005.2  2005.3   2005.4  2005.5  \
# 0   혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)   RH(+)
# 1   혈액원별(2)  성별(1)       소계       소계       소계      O형       O형      A형
# 2   혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)  실적 (건)
# 3        소계      계  2274336  2265832     99.6  620195     27.3  772270
# 4        소계      남  1831613  1825105     99.6  498226     27.2  626711
# 5        소계      여   442723   440727     99.5  121969     27.5  145559
# 6        소계      계  2223636  2215240     99.6  606013     27.3  755806
# 7        소계      남  1789525  1783096     99.6  486553     27.2  612942
# 8        소계      여   434111   432144     99.5  119460     27.5  142864
# 9      서울중앙      계   210606   209810     99.6   56961     27.0   70681
# 10     서울중앙      남   169824   169215     99.6   45967     27.1   57467
# 11     서울중앙      여    40782    40595     99.5   10994     27.0   13214
# ...

# %%
blood = pd.read_csv('blood data/혈액형별_헌혈통계_2005_2019.csv', encoding = 'cp949',header= None)
blood
# Out:
#          0        1      2        3        4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  2265832     99.6  620195     27.3
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    24867     99.6    6807     27.3
# 57    대한적십자사       제주      여     6706     6680     99.6    1771     26.4
# 58  대한적십자사 외       소계      계    50700    50592     99.8   14182     28.0
# 59  대한적십자사 외       소계      남    42088    42009     99.8   11673     27.7
# 60  대한적십자사 외       소계      여     8612     8583     99.7    2509     29.1
#
#        8        9    ...     308      309     310      311     312      313  \
# ...

# %%
blood_co= blood.copy()
blood_co
# Out:
#          0        1      2        3        4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  2265832     99.6  620195     27.3
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    24867     99.6    6807     27.3
# 57    대한적십자사       제주      여     6706     6680     99.6    1771     26.4
# 58  대한적십자사 외       소계      계    50700    50592     99.8   14182     28.0
# 59  대한적십자사 외       소계      남    42088    42009     99.8   11673     27.7
# 60  대한적십자사 외       소계      여     8612     8583     99.7    2509     29.1
#
#        8        9    ...     308      309     310      311     312      313  \
# ...

# %%
blood_RH =blood_co.rename(columns=blood_co.iloc[0])

# %%
blood_2005 = blood_RH[['혈액원별(1)','혈액원별(2)','성별(1)','2005']]
blood_2005
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  2265832     99.6  620195     27.3
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    24867     99.6    6807     27.3
# 57    대한적십자사       제주      여     6706     6680     99.6    1771     26.4
# 58  대한적십자사 외       소계      계    50700    50592     99.8   14182     28.0
# 59  대한적십자사 외       소계      남    42088    42009     99.8   11673     27.7
# 60  대한적십자사 외       소계      여     8612     8583     99.7    2509     29.1
#
#       2005     2005  ...    2005     2005    2005     2005    2005     2005  \
# ...

# %%
blood_2005_RHp = blood_2005.iloc[:, 0:14]
blood_2005_RHp
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  2265832     99.6  620195     27.3
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    24867     99.6    6807     27.3
# 57    대한적십자사       제주      여     6706     6680     99.6    1771     26.4
# 58  대한적십자사 외       소계      계    50700    50592     99.8   14182     28.0
# 59  대한적십자사 외       소계      남    42088    42009     99.8   11673     27.7
# 60  대한적십자사 외       소계      여     8612     8583     99.7    2509     29.1
#
#       2005     2005    2005     2005    2005     2005
# ...

# %%
blood_co2 = blood_co.drop(columns=[0],index=0)
blood_co
# Out:
#          0        1      2        3        4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)    RH(+)   RH(+)    RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계      O형       O형
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  2265832     99.6  620195     27.3
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    24867     99.6    6807     27.3
# 57    대한적십자사       제주      여     6706     6680     99.6    1771     26.4
# 58  대한적십자사 외       소계      계    50700    50592     99.8   14182     28.0
# 59  대한적십자사 외       소계      남    42088    42009     99.8   11673     27.7
# 60  대한적십자사 외       소계      여     8612     8583     99.7    2509     29.1
#
#        8        9    ...     308      309     310      311     312      313  \
# ...

# %%
blood_co2 = blood_co.rename(columns=blood_co.iloc[3])
blood_co3= blood_co2.drop(columns='구성비 (%)', index=3)

# %%
blood_co3
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  실적 (건)  실적 (건)  실적 (건)  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005    2005    2005    2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    RH(+)   RH(+)   RH(+)   RH(+)
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계      O형      A형      B형
# 4         합계       소계      계  2274336  2265832  620195  772270  613836
# 5         합계       소계      남  1831613  1825105  498226  626711  491213
# 6         합계       소계      여   442723   440727  121969  145559  122623
# 7     대한적십자사       소계      계  2223636  2215240  606013  755806  600138
# 8     대한적십자사       소계      남  1789525  1783096  486553  612942  479867
# 9     대한적십자사       소계      여   434111   432144  119460  142864  120271
# 10    대한적십자사     서울중앙      계   210606   209810   56961   70681   57520
# 11    대한적십자사     서울중앙      남   169824   169215   45967   57467   46008
# 12    대한적십자사     서울중앙      여    40782    40595   10994   13214   11512
# ...

# %%
blood_co4 = blood_co3.iloc[:,1:3]
blood_co4
# Out:
#     혈액원별(2)  성별(1)
# 0   혈액원별(2)  성별(1)
# 1   혈액원별(2)  성별(1)
# 2   혈액원별(2)  성별(1)
# 4        소계      계
# 5        소계      남
# 6        소계      여
# 7        소계      계
# 8        소계      남
# 9        소계      여
# 10     서울중앙      계
# 11     서울중앙      남
# 12     서울중앙      여
# 13     서울서부      계
# 14     서울서부      남
# 15     서울서부      여
# 16     서울남부      계
# 17     서울남부      남
# 18     서울남부      여
# 19     서울동부      계
# 20     서울동부      남
# 21     서울동부      여
# 22       부산      계
# 23       부산      남
# 24       부산      여
# 25     대구경북      계
# 26     대구경북      남
# 27     대구경북      여
# 28       인천      계
# 29       인천      남
# 30       인천      여
# 31       울산      계
# 32       울산      남
# 33       울산      여
# 34       경기      계
# 35       경기      남
# 36       경기      여
# 37       강원      계
# 38       강원      남
# 39       강원      여
# 40       충북      계
# 41       충북      남
# 42       충북      여
# 43   대전세종충남      계
# 44   대전세종충남      남
# 45   대전세종충남      여
# 46       전북      계
# ...

# %%
blood_co5  = blood_co3.iloc[:,36:]
blood_co5
# Out:
#      실적 (건)   실적 (건)  실적 (건)  실적 (건)  실적 (건)  실적 (건) 실적 (건) 실적 (건) 실적 (건)  \
# 0      2008     2008    2008    2008    2008    2008   2008   2008   2008
# 1        합계    RH(+)   RH(+)   RH(+)   RH(+)   RH(+)  RH(-)  RH(-)  RH(-)
# 2        소계       소계      O형      A형      B형     AB형     소계     O형     A형
# 4   2347184  2338157  640707  800197  628496  268757   9027   2539   3063
# 5   1741184  1734766  474347  598469  463266  198684   6418   1785   2201
# 6    606000   603391  166360  201728  165230   70073   2609    754    862
# 7   2265592  2256787  618401  772400  606669  259317   8805   2455   2990
# 8   1677786  1671524  457082  576618  446448  191376   6262   1724   2148
# 9    587806   585263  161319  195782  160221   67941   2543    731    842
# 10   207970   207187   57141   69970   56391   23685    783    202    288
# 11   147238   146738   40468   49904   39612   16754    500    127    184
# 12    60732    60449   16673   20066   16779    6931    283     75    104
# ...

# %%
result = pd.concat([blood_co4, blood_co5], axis=1)
result
# Out:
#     혈액원별(2)  성별(1)   실적 (건)   실적 (건)  실적 (건)  실적 (건)  실적 (건)  실적 (건) 실적 (건)  \
# 0   혈액원별(2)  성별(1)     2008     2008    2008    2008    2008    2008   2008
# 1   혈액원별(2)  성별(1)       합계    RH(+)   RH(+)   RH(+)   RH(+)   RH(+)  RH(-)
# 2   혈액원별(2)  성별(1)       소계       소계      O형      A형      B형     AB형     소계
# 4        소계      계  2347184  2338157  640707  800197  628496  268757   9027
# 5        소계      남  1741184  1734766  474347  598469  463266  198684   6418
# 6        소계      여   606000   603391  166360  201728  165230   70073   2609
# 7        소계      계  2265592  2256787  618401  772400  606669  259317   8805
# 8        소계      남  1677786  1671524  457082  576618  446448  191376   6262
# 9        소계      여   587806   585263  161319  195782  160221   67941   2543
# 10     서울중앙      계   207970   207187   57141   69970   56391   23685    783
# 11     서울중앙      남   147238   146738   40468   49904   39612   16754    500
# ...

# %%
range(0, len(result.columns))
# Out:
# range(0, 134)

# %%
columns = []
for i in range(0, len(result.columns)):
    columns.append(i)

# %%
result.columns=columns

# %%
result.to_csv('data_bloodtype(실적).csv', encoding= 'CP949', index=False, header=None)
