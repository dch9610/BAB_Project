# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
import datetime
import seaborn as sns
# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# %%
blood= pd.read_csv('blood data/혈액공급실적_2005_2019.csv', encoding = 'CP949')
blood
# Out:
#     혈액원별(1)     2005      2005.1      2005.2      2005.3  2005.4      2005.5  \
# 0   혈액원별(1)     헌혈실적       제제생산량        공급합계         수혈용     수혈용         수혈용
# 1   혈액원별(1)       소계          소계          소계          소계      소계       적혈구제제
# 2   혈액원별(1)   실적 (건)  혈액량 (unit)  혈액량 (unit)  혈액량 (unit)  비율 (%)  혈액량 (unit)
# 3        합계  2223636     5168535     4931499     3472979       -     1582004
# 4      서울중앙   210606      539340      573101      459331    80.1      168949
# 5      서울서부   133579      300644      285247      221697    77.7       93919
# 6      서울남부   180865      481788      521527      432297    82.9      150427
# 7      서울동부   195539      474953      448972      328882    73.3      157005
# 8        부산   213224      479881      457402      332242    72.6      146509
# 9      대구경북   194152      420592      402591      270341    67.2      144308
# 10       인천   129274      308847      287984      192044    66.7      102589
# ...

# %%
blood.isna().sum()
# Out:
# 혈액원별(1)    0
# 2005       0
# 2005.1     0
# 2005.2     0
# 2005.3     0
#           ..
# 2019.16    0
# 2019.17    0
# 2019.18    0
# 2019.19    0
# 2019.20    0
# Length: 317, dtype: int64

# %%
blood_T = blood.T

# %%
blood_T2 = blood_T.rename(columns=blood_T.iloc[0]).drop(index='혈액원별(1)')
blood_T2
# Out:
#         혈액원별(1)      혈액원별(1)     혈액원별(1)       합계    서울중앙    서울서부    서울남부  \
# 2005       헌혈실적           소계      실적 (건)  2223636  210606  133579  180865
# 2005.1    제제생산량           소계  혈액량 (unit)  5168535  539340  300644  481788
# 2005.2     공급합계           소계  혈액량 (unit)  4931499  573101  285247  521527
# 2005.3      수혈용           소계  혈액량 (unit)  3472979  459331  221697  432297
# 2005.4      수혈용           소계      비율 (%)        -    80.1    77.7    82.9
# ...         ...          ...         ...      ...     ...     ...     ...
# 2019.16     분획용    전혈유래 혈장제제      비율 (%)     21.9    11.1       -    20.7
# 2019.17     분획용    성분채혈 혈장제제  혈액량 (unit)   438709   39413       -   39808
# 2019.18     분획용    성분채혈 혈장제제      비율 (%)      6.9     4.8       -     7.4
# 2019.19     분획용  다종성분채혈 혈장제제  혈액량 (unit)   194831   31777       -   16592
# 2019.20     분획용  다종성분채혈 혈장제제      비율 (%)      3.1     3.9       -     3.1
#
#            서울동부      부산    대구경북      인천      울산      경기      강원      충북  \
# ...

# %%
columns= []
for i in blood_T2.columns:
#     print(i)
    columns.append(i)

    
columns
# Out:
# ['혈액원별(1)',
#  '혈액원별(1)',
#  '혈액원별(1)',
#  '합계',
#  '서울중앙',
#  '서울서부',
#  '서울남부',
#  '서울동부',
#  '부산',
#  '대구경북',
#  '인천',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '대전세종충남',
#  '전북',
#  '광주전남',
#  '경남',
#  '제주']

# %%
columns= ['혈액원별(1)','혈액원별(2)',
 '혈액원별(3)',
 '합계',
 '서울중앙',
 '서울서부',
 '서울남부',
 '서울동부',
 '부산',
 '대구경북',
 '인천',
 '울산',
 '경기',
 '강원',
 '충북',
 '대전세종충남',
 '전북',
 '광주전남',
 '경남',
 '제주' ]

# %%
columns
# Out:
# ['혈액원별(1)',
#  '혈액원별(2)',
#  '혈액원별(3)',
#  '합계',
#  '서울중앙',
#  '서울서부',
#  '서울남부',
#  '서울동부',
#  '부산',
#  '대구경북',
#  '인천',
#  '울산',
#  '경기',
#  '강원',
#  '충북',
#  '대전세종충남',
#  '전북',
#  '광주전남',
#  '경남',
#  '제주']

# %%
blood_T2.columns=columns

# %%
blood_vol =  blood_T2[blood_T2['혈액원별(1)'].str.contains('헌혈실적')]
blood_vol2 = blood_T2[blood_T2['혈액원별(1)'].str.contains('공급합계')]

# %%
blood_T3=pd.concat([blood_vol, blood_vol2])
blood_T3.sort_index(inplace=True)
blood_T3
# Out:
#        혈액원별(1) 혈액원별(2)     혈액원별(3)       합계    서울중앙    서울서부    서울남부    서울동부  \
# 2005      헌혈실적      소계      실적 (건)  2223636  210606  133579  180865  195539
# 2005.2    공급합계      소계  혈액량 (unit)  4931499  573101  285247  521527  448972
# 2006      헌혈실적      소계      실적 (건)  2250603  222081  138596  189797  200418
# 2006.2    공급합계      소계  혈액량 (unit)  5120827  598154  310015  544737  474846
# 2007      헌혈실적      소계      실적 (건)  2028684  187792  154934  172800  181977
# 2007.2    공급합계      소계  혈액량 (unit)  4993794  564960  320503  547351  492055
# 2008      헌혈실적      소계      실적 (건)  2265592  207970  170843  187157  198135
# 2008.2    공급합계      소계  혈액량 (unit)  5453104  580750  349207  651670  518252
# 2009      헌혈실적      소계      실적 (건)  2461880  208524  193223  208521  213194
# 2009.2    공급합계      소계  혈액량 (unit)  5857967  587616  424525  689261  526804
# 2010      헌혈실적      소계      실적 (건)  2461880  208524  193223  208521  213194
# ...

# %%
blood_vol_int = blood_vol.iloc[:,3:]
blood_vol_int
# Out:
#            합계    서울중앙    서울서부    서울남부    서울동부      부산    대구경북      인천     울산  \
# 2005  2223636  210606  133579  180865  195539  213224  194152  129274  78750
# 2006  2250603  222081  138596  189797  200418  212569  188941  120981  82109
# 2007  2028684  187792  154934  172800  181977  189623  157399  110095  65432
# 2008  2265592  207970  170843  187157  198135  210269  188025  121802  71284
# 2009  2461880  208524  193223  208521  213194  216812  215479  130869  73928
# 2010  2461880  208524  193223  208521  213194  216812  215479  130869  73928
# 2011  2448516       -  271598  217957  265040  217017  211723  174910  73504
# 2012  2542495       -  283170  228981  276024  218875  226824  173438  79081
# 2013  2708173       -  302603  235251  295350  230923  244750  177812  81305
# 2014  2844538       -  334796  229574  315316  235796  263765  185747  89410
# 2015  2872156       -  332287  224175  298738  238001  260227  180847  93740
# ...

# %%
blood_vol_int= blood_vol_int.replace('-',f'0')
blood_vol_int= blood_vol_int.astype(int)
blood_vol_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 2005 to 2019
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   합계      15 non-null     int32
#  1   서울중앙    15 non-null     int32
#  2   서울서부    15 non-null     int32
#  3   서울남부    15 non-null     int32
#  4   서울동부    15 non-null     int32
#  5   부산      15 non-null     int32
#  6   대구경북    15 non-null     int32
#  7   인천      15 non-null     int32
#  8   울산      15 non-null     int32
#  9   경기      15 non-null     int32
#  10  강원      15 non-null     int32
#  11  충북      15 non-null     int32
#  12  대전세종충남  15 non-null     int32
#  13  전북      15 non-null     int32
#  14  광주전남    15 non-null     int32
#  15  경남      15 non-null     int32
#  16  제주      15 non-null     int32
# dtypes: int32(17)
# memory usage: 1.1+ KB

# %%
blood_vol_int['서울중앙'].replace(0,f'{int(blood_vol_int["서울중앙"].mean())}', inplace=True)
blood_vol_int['서울서부'].replace(0,f'{int(blood_vol_int["서울서부"].mean())}', inplace=True)

# %%
blood_vol_int= blood_vol_int.astype(int)
blood_vol_int
# Out:
#            합계    서울중앙    서울서부    서울남부    서울동부      부산    대구경북      인천     울산  \
# 2005  2223636  210606  133579  180865  195539  213224  194152  129274  78750
# 2006  2250603  222081  138596  189797  200418  212569  188941  120981  82109
# 2007  2028684  187792  154934  172800  181977  189623  157399  110095  65432
# 2008  2265592  207970  170843  187157  198135  210269  188025  121802  71284
# 2009  2461880  208524  193223  208521  213194  216812  215479  130869  73928
# 2010  2461880  208524  193223  208521  213194  216812  215479  130869  73928
# 2011  2448516  117540  271598  217957  265040  217017  211723  174910  73504
# 2012  2542495  117540  283170  228981  276024  218875  226824  173438  79081
# 2013  2708173  117540  302603  235251  295350  230923  244750  177812  81305
# 2014  2844538  117540  334796  229574  315316  235796  263765  185747  89410
# 2015  2872156  117540  332287  224175  298738  238001  260227  180847  93740
# ...

# %%
plt.plot(blood_vol_int.iloc[:,1:])
plt.show()

# %%
blood_vol2_int=blood_vol2.iloc[:,3:]
blood_vol2_int
# Out:
#              합계    서울중앙    서울서부    서울남부    서울동부      부산    대구경북      인천  \
# 2005.2  4931499  573101  285247  521527  448972  457402  402591  287984
# 2006.2  5120827  598154  310015  544737  474846  462020  408548  290425
# 2007.2  4993794  564960  320503  547351  492055  449576  393277  284286
# 2008.2  5453104  580750  349207  651670  518252  492470  447889  314429
# 2009.2  5857967  587616  424525  689261  526804  495622  498913  331562
# 2010.2  6018358  688292  206013  672922  624088  547285  504448  358406
# 2011.2  5974089       -  803345  664665  671957  558155  502990  370249
# 2012.2  6124156       -  799190  655566  687848  561970  526716  368180
# 2013.2  6186007       -  784510  612439  695466  569867  551044  367264
# 2014.2  6272253       -  819332  562954  683149  567199  560998  384318
# 2015.2  6278079       -  796520  547272  663377  563760  546564  382091
# 2016.2  5891875       -  741841  544925  635035  520327  514241  343170
# ...
