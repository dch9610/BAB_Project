# %%
import pandas as pd

# %%
people = pd.read_csv('blood data/월별 인구 통계.csv', encoding = 'CP949')

# %%
people2 = people.drop(columns='단위')

# %%
people3 = people2.iloc[4].reset_index()

# %%
people4 = people3.drop(index=[0,1,2, 160])

# %%
people4.columns= ['날짜','인구 증감']
people4
# Out:
#              날짜  인구 증감
# 3    2008. 01 월  24902
# 4    2008. 02 월  18439
# 5    2008. 03 월  18709
# 6    2008. 04 월  18524
# 7    2008. 05 월  17281
# ..          ...    ...
# 155  2020. 09 월   -882
# 156  2020. 10 월  -4637
# 157  2020. 11 월  -5578
# 158  2020. 12 월  -7323
# 159  2021. 01 월  -2177
#
# [157 rows x 2 columns]

# %%
people4.to_csv('월별 인구 증감.csv', encoding='CP949')

# %%
people
# Out:
#        행정구역별         종류별           항목  단위 2008. 01 월 2008. 02 월 2008. 03 월  \
# 0         전국     출생아수(명)  출생,사망,혼인,이혼 NaN      46747      39495      41318
# 1         전국   조출생률(천명당)  출생,사망,혼인,이혼 NaN       11.2      10.11       9.89
# 2         전국     사망자수(명)  출생,사망,혼인,이혼 NaN      21845      21056      22609
# 3         전국   조사망률(천명당)  출생,사망,혼인,이혼 NaN        5.2        5.4        5.4
# 4         전국   자연증가건수(명)  출생,사망,혼인,이혼 NaN      24902      18439      18709
# ..       ...         ...          ...  ..        ...        ...        ...
# 175  제주특별자치도  자연증가율(천명당)  출생,사망,혼인,이혼 NaN        6.1        4.4        5.3
# 176  제주특별자치도     혼인건수(건)  출생,사망,혼인,이혼 NaN        315        295        324
# 177  제주특별자치도   조혼인율(천명당)  출생,사망,혼인,이혼 NaN        6.7        6.7        6.8
# 178  제주특별자치도     이혼건수(건)  출생,사망,혼인,이혼 NaN        125        115        105
# 179  제주특별자치도   조이혼율(천명당)  출생,사망,혼인,이혼 NaN        2.6        2.6        2.2
#
# ...

# %%
people2 = people.drop(columns='단위')

# %%
people3 = people2[people2['종류별'].str.contains('자연증가건수')]
people4 = people3.drop(columns= ['종류별','항목'])
people5 = people4.set_index('행정구역별')
people5
# Out:
#         2008. 01 월 2008. 02 월 2008. 03 월 2008. 04 월 2008. 05 월 2008. 06 월  \
# 행정구역별
# 전국           24902      18439      18709      18524      17281      16234
# 서울특별시         6240       4945       5002       4740       4495       4292
# 부산광역시          898        523        620        657        481        398
# 대구광역시         1033        743        737        799        690        717
# 인천광역시         1388       1086       1316       1217       1129       1046
# 광주광역시          925        700        624        653        586        602
# 대전광역시         1039        682        684        761        732        664
# 울산광역시          685        578        637        623        556        578
# 세종특별자치시        NaN        NaN        NaN        NaN        NaN        NaN
# 경기도           8135       6604       6471       6244       6063       5568
# 강원도            361        185        160         70        101        136
# 충청북도           530        356        371        314        297        363
# ...

# %%
people5.to_csv('지역별 인구 증감.csv', encoding= 'CP949')

# %%
people5
# Out:
#         2008. 01 월 2008. 02 월 2008. 03 월 2008. 04 월 2008. 05 월 2008. 06 월  \
# 행정구역별
# 전국           24902      18439      18709      18524      17281      16234
# 서울특별시         6240       4945       5002       4740       4495       4292
# 부산광역시          898        523        620        657        481        398
# 대구광역시         1033        743        737        799        690        717
# 인천광역시         1388       1086       1316       1217       1129       1046
# 광주광역시          925        700        624        653        586        602
# 대전광역시         1039        682        684        761        732        664
# 울산광역시          685        578        637        623        556        578
# 세종특별자치시        NaN        NaN        NaN        NaN        NaN        NaN
# 경기도           8135       6604       6471       6244       6063       5568
# 강원도            361        185        160         70        101        136
# 충청북도           530        356        371        314        297        363
# ...
