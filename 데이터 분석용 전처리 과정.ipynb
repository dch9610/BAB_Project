# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
import datetime
import seaborn as sns
# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# %%
blood_age = pd.read_csv('blood data/연령별_헌혈통계_2005_2019.csv', encoding= 'CP949')
blood_age
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)     2005  2005.1   2005.2   2005.3   2005.4  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)       합계  16~19세   16~19세   20~29세   20~29세
# 1    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)  실적 (건)  구성비 (%)   실적 (건)  구성비 (%)
# 2         합계       소계      계  2274336  707262     31.1  1159926     51.0
# 3         합계       소계      남  1831613  490644     26.8   980749     53.5
# 4         합계       소계      여   442723  216618     48.9   179177     40.5
# 5     대한적십자사       소계      계  2223636  698597     31.4  1133547     51.0
# 6     대한적십자사       소계      남  1789525  483940     27.0   958694     53.6
# 7     대한적십자사       소계      여   434111  214657     49.4   174853     40.3
# 8     대한적십자사     서울중앙      계   210606   47506     22.6   129942     61.7
# 9     대한적십자사     서울중앙      남   169824   31241     18.4   110065     64.8
# 10    대한적십자사     서울중앙      여    40782   16265     39.9    19877     48.7
# 11    대한적십자사     서울서부      계   133579   36944     27.7    70382     52.7
# ...

# %%
blood_age2 = blood_age.drop(index=[2,3,4])
blood_age2
# Out:
#      혈액원별(1)  혈액원별(2)  성별(1)     2005  2005.1   2005.2   2005.3   2005.4  \
# 0    혈액원별(1)  혈액원별(2)  성별(1)       합계  16~19세   16~19세   20~29세   20~29세
# 1    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)  실적 (건)  구성비 (%)   실적 (건)  구성비 (%)
# 5     대한적십자사       소계      계  2223636  698597     31.4  1133547     51.0
# 6     대한적십자사       소계      남  1789525  483940     27.0   958694     53.6
# 7     대한적십자사       소계      여   434111  214657     49.4   174853     40.3
# 8     대한적십자사     서울중앙      계   210606   47506     22.6   129942     61.7
# 9     대한적십자사     서울중앙      남   169824   31241     18.4   110065     64.8
# 10    대한적십자사     서울중앙      여    40782   16265     39.9    19877     48.7
# 11    대한적십자사     서울서부      계   133579   36944     27.7    70382     52.7
# 12    대한적십자사     서울서부      남   113857   28189     24.8    61835     54.3
# 13    대한적십자사     서울서부      여    19722    8755     44.4     8547     43.3
# 14    대한적십자사     서울남부      계   180865   41514     23.0   103952     57.5
# ...

# %%
blood_age3 = blood_age2.T
blood_age4 = blood_age3[blood_age3[1].str.contains('실적|성별|혈액원')]
blood_age4 = blood_age4.iloc[:, :53]
blood_age4
# Out:
#               0        1        5        6       7       8       9       10  \
# 혈액원별(1)  혈액원별(1)  혈액원별(1)   대한적십자사   대한적십자사  대한적십자사  대한적십자사  대한적십자사  대한적십자사
# 혈액원별(2)  혈액원별(2)  혈액원별(2)       소계       소계      소계    서울중앙    서울중앙    서울중앙
# 성별(1)      성별(1)    성별(1)        계        남       여       계       남       여
# 2005          합계   실적 (건)  2223636  1789525  434111  210606  169824   40782
# 2005.1    16~19세   실적 (건)   698597   483940  214657   47506   31241   16265
# ...          ...      ...      ...      ...     ...     ...     ...     ...
# 2019.3    20~29세   실적 (건)   955947   729930  226017  100468   75678   24790
# 2019.5    30~39세   실적 (건)   396869   311135   85734   44972   34284   10688
# 2019.7    40~49세   실적 (건)   332103   260254   71849   33505   25887    7618
# 2019.9    50~59세   실적 (건)   146380   116474   29906   14970   11698    3272
# 2019.11    60세이상   실적 (건)    26495    21745    4750    3383    2795     588
#
# ...

# %%
blood_age5 = blood_age4.drop(index='혈액원별(1)')
blood_age5 = blood_age5.rename(columns= blood_age5.iloc[1])
blood_age5 = blood_age5.drop(index='성별(1)')
blood_age5
# Out:
#            성별(1)    성별(1)        계        남       여       계       남      여  \
# 혈액원별(2)  혈액원별(2)  혈액원별(2)       소계       소계      소계    서울중앙    서울중앙   서울중앙
# 2005          합계   실적 (건)  2223636  1789525  434111  210606  169824  40782
# 2005.1    16~19세   실적 (건)   698597   483940  214657   47506   31241  16265
# 2005.3    20~29세   실적 (건)  1133547   958694  174853  129942  110065  19877
# 2005.5    30~39세   실적 (건)   273032   244660   28372   22747   19642   3105
# ...          ...      ...      ...      ...     ...     ...     ...    ...
# 2019.3    20~29세   실적 (건)   955947   729930  226017  100468   75678  24790
# 2019.5    30~39세   실적 (건)   396869   311135   85734   44972   34284  10688
# 2019.7    40~49세   실적 (건)   332103   260254   71849   33505   25887   7618
# 2019.9    50~59세   실적 (건)   146380   116474   29906   14970   11698   3272
# 2019.11    60세이상   실적 (건)    26495    21745    4750    3383    2795    588
#
# ...

# %%
blood_age6 = blood_age5.T
blood_age7 = blood_age6[blood_age6['혈액원별(2)'].str.contains('혈액원별|소계')]
blood_age7
# Out:
#        혈액원별(2)     2005  2005.1   2005.3  2005.5  2005.7  2005.9 2005.11  \
# 성별(1)  혈액원별(2)       합계  16~19세   20~29세  30~39세  40~49세  50~59세   60세이상
# 성별(1)  혈액원별(2)   실적 (건)  실적 (건)   실적 (건)  실적 (건)  실적 (건)  실적 (건)  실적 (건)
# 계           소계  2223636  698597  1133547  273032   92702   23922    1836
# 남           소계  1789525  483940   958694  244660   79682   20935    1614
# 여           소계   434111  214657   174853   28372   13020    2987     222
#
#           2006  2006.1  ...  2018.7  2018.9 2018.11     2019  2019.1  2019.3  \
# 성별(1)       합계  16~19세  ...  40~49세  50~59세   60세이상       합계  16~19세  20~29세
# 성별(1)   실적 (건)  실적 (건)  ...  실적 (건)  실적 (건)  실적 (건)   실적 (건)  실적 (건)  실적 (건)
# 계      2250603  750951  ...  303575  122562   21806  2613901  756107  955947
# 남      1748275  494791  ...  239577   98995   18188  1909232  469694  729930
# 여       502328  256160  ...   63998   23567    3618   704669  286413  226017
#
#        2019.5  2019.7  2019.9 2019.11
# ...

# %% [markdown]
# ## 분기 포인트

# %%
blood_age8 = blood_age7.T
blood_age8.columns = ['성별(1)','성별(2)','계','남','여']
blood_age9 = blood_age8[blood_age8['성별(1)'].str.contains('합계')]
blood_age9[['남','여']]
# Out:
#             남       여
# 2005  1789525  434111
# 2006  1748275  502328
# 2007  1545871  482813
# 2008  1677795  587797
# 2009  1799095  662785
# 2010  1797670  717029
# 2011  1717257  731259
# 2012  1790590  751905
# 2013  1909293  798880
# 2014  2007168  837370
# 2015  2029746  842410
# 2016  1926108  719073
# 2017  1988861  725958
# 2018  1972773  708838
# 2019  1909232  704669

# %%
# 각 년도별 남, 여의 수 비교
blood_sex = blood_age9[['남','여']]
blood_sex = blood_sex.astype(int)
blood_sex
# Out:
#             남       여
# 2005  1789525  434111
# 2006  1748275  502328
# 2007  1545871  482813
# 2008  1677795  587797
# 2009  1799095  662785
# 2010  1797670  717029
# 2011  1717257  731259
# 2012  1790590  751905
# 2013  1909293  798880
# 2014  2007168  837370
# 2015  2029746  842410
# 2016  1926108  719073
# 2017  1988861  725958
# 2018  1972773  708838
# 2019  1909232  704669

# %%
## 년도별 남녀 헌혈실적 비교 그래프
plt.plot(blood_sex)
plt.title('년도별 남녀 헌혈실적 비교')
plt.legend(blood_sex.columns)
plt.show()

# %%
# 연령별로 남녀 구분가능한가
blood_age_sex = blood_age8.drop(columns= '성별(2)')
blood_age_sex = blood_age_sex[['성별(1)','남','여']].drop(index='혈액원별(2)')
a1 = blood_age_sex[blood_age_sex['성별(1)'].str.contains('합계')].index

# %%
blood_age_sex2 = blood_age_sex.drop(index=a1)
blood_age_sex2.columns = ['나이','남','여']
blood_age_sex2.T
# Out:
#     2005.1  2005.3  2005.5  2005.7  2005.9 2005.11  2006.1  2006.3  2006.5  \
# 나이  16~19세  20~29세  30~39세  40~49세  50~59세   60세이상  16~19세  20~29세  30~39세
# 남   483940  958694  244660   79682   20935    1614  494791  915791  224238
# 여   214657  174853   28372   13020    2987     222  256160  194432   33171
#
#     2006.7  ...  2018.5  2018.7  2018.9 2018.11  2019.1  2019.3  2019.5  \
# 나이  40~49세  ...  30~39세  40~49세  50~59세   60세이상  16~19세  20~29세  30~39세
# 남    87469  ...  309667  239577   98995   18188  469694  729930  311135
# 여    14883  ...   83031   63998   23567    3618  286413  226017   85734
#
#     2019.7  2019.9 2019.11
# 나이  40~49세  50~59세   60세이상
# 남   260254  116474   21745
# 여    71849   29906    4750
#
# [3 rows x 90 columns]

# %%
column = []
for i in range(2005,2020):
    for n in range(6):
        column.append(f'{i}')
        
# column
# Out:
# ['2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019']

# %%
blood_age_sex3 = blood_age_sex2.T
blood_age_sex3.columns = column
blood_age_sex3 = blood_age_sex3.drop(columns= ['2005','2006','2007'])
blood_age_sex4 = blood_age_sex3.T.reset_index().set_index(['index','나이'])
blood_age_sex4
# Out:
#                    남       여
# index 나이
# 2008  16~19세  517117  310072
#       20~29세  789826  214132
#       30~39세  243034   40823
#       40~49세   95608   17818
#       50~59세   29334    4647
# ...              ...     ...
# 2019  20~29세  729930  226017
#       30~39세  311135   85734
#       40~49세  260254   71849
#       50~59세  116474   29906
#       60세이상    21745    4750
#
# [72 rows x 2 columns]

# %%
blood_age_sex4 = blood_age_sex4.astype(int)
blood_age_sex4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 72 entries, ('2008', '16~19세') to ('2019', '60세이상')
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   남       72 non-null     int32
#  1   여       72 non-null     int32
# dtypes: int32(2)
# memory usage: 996.0+ bytes

# %%
for i in range(2008,2020):
    ax = blood_age_sex4.loc[f'{i}'].plot(kind='bar', title=f'{i}년 연령별 남녀 비율',figsize=(12, 8), legend=True, fontsize=12)
    ax.set_xlabel('연령별', fontsize=20)
    ax.set_ylabel('실적 수', fontsize=20)
    ax.set_ylim(ymax = 1000000)
    plt.show()

# %% [markdown]
# ## 직업별에서 군인비율 확인해서 빼고 생각해보자

# %%
blood_job = pd.read_csv('blood data/직업별_헌혈통계_2005_2019.csv', encoding= 'CP949', header= None)
blood_job
# Out:
#          0        1      2        3       4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005    2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계    고등학생     고등학생     대학생      대학생
# 2    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)  실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 3         합계       소계      계  2274336  424784     18.7  544828     24.0
# 4         합계       소계      남  1831613  280052     15.3  385396     21.0
# 5         합계       소계      여   442723  144732     32.7  159432     36.0
# 6     대한적십자사       소계      계  2223636  422460     19.0  528572     23.8
# 7     대한적십자사       소계      남  1789525  278216     15.5  372246     20.8
# 8     대한적십자사       소계      여   434111  144244     33.2  156326     36.0
# 9     대한적십자사     서울중앙      계   210606   29731     14.1   43668     20.7
# 10    대한적십자사     서울중앙      남   169824   18858     11.1   29348     17.3
# 11    대한적십자사     서울중앙      여    40782   10873     26.7   14320     35.1
# ...

# %%
blood_job.T
# Out:
#           0        1        2        3        4       5        6        7   \
# 0    혈액원별(1)  혈액원별(1)  혈액원별(1)       합계       합계      합계   대한적십자사   대한적십자사
# 1    혈액원별(2)  혈액원별(2)  혈액원별(2)       소계       소계      소계       소계       소계
# 2      성별(1)    성별(1)    성별(1)        계        남       여        계        남
# 3       2005       합계   실적 (건)  2274336  1831613  442723  2223636  1789525
# 4       2005     고등학생   실적 (건)   424784   280052  144732   422460   278216
# ..       ...      ...      ...      ...      ...     ...      ...      ...
# 283     2019      종교직  구성비 (%)      0.2      0.2     0.1      0.2      0.2
# 284     2019       가사   실적 (건)    51255      148   51107    48236      115
# 285     2019       가사  구성비 (%)      1.8        -     6.8      1.8        -
# 286     2019       기타   실적 (건)   255721   184125   71596   233267   167873
# 287     2019       기타  구성비 (%)      9.2      9.0     9.5      8.9      8.8
#
# ...

# %%
blood_job2 = blood_job.T[blood_job.T[2].str.contains('실적|혈액|성별')]
blood_job3 = blood_job2.drop(columns = [2,3,4,5,57,58,59])
blood_job3 = blood_job3.drop(index=[0])
blood_job3
# Out:
#           0        1        6        7       8       9       10     11  \
# 1    혈액원별(2)  혈액원별(2)       소계       소계      소계    서울중앙    서울중앙   서울중앙
# 2      성별(1)    성별(1)        계        남       여       계       남      여
# 3       2005       합계  2223636  1789525  434111  210606  169824  40782
# 4       2005     고등학생   422460   278216  144244   29731   18858  10873
# 6       2005      대학생   528572   372246  156326   43668   29348  14320
# ..       ...      ...      ...      ...     ...     ...     ...    ...
# 278     2019      공무원    90712    74739   15973    4912    4039    873
# 280     2019      자영업    51979    47158    4821    5780    5256    524
# 282     2019      종교직     5074     4593     481     570     509     61
# 284     2019       가사    48236      115   48121    4627       8   4619
# 286     2019       기타   233267   167873   65394   27174   19324   7850
#
#          12      13  ...     47      48      49     50      51     52     53  \
# ...

# %%
# 연도별 군인 헌혈실적만 가져온다.
blood_job4 = blood_job3[blood_job3[1].str.contains('군인|성별|혈액원별')]
blood_job5 = blood_job4.T[blood_job4.T[1].str.contains('혈액원|소계')].T.drop(index=1)
blood_job5 = blood_job5.rename(columns = blood_job5.iloc[0])
blood_job5 = blood_job5.drop(index=2 )
blood_job6 = blood_job5.T
blood_job6 = blood_job6.rename(columns = blood_job6.iloc[0])
blood_job6 = blood_job6.drop(index='성별(1)')
blood_job7 = blood_job6.drop(columns=['2005','2006','2007'])
blood_job7= blood_job7.T
blood_job7
# Out:
#            계       남     여
# 2008  378552  377220  1332
# 2009  372983  371211  1772
# 2010  342455  340591  1864
# 2011  310272  308257  2015
# 2012  358640  356043  2597
# 2013  406560  403039  3521
# 2014  417257  413415  3842
# 2015  438359  434167  4192
# 2016  447225  443597  3628
# 2017  450868  447142  3726
# 2018  430820  426788  4032
# 2019  379748  374811  4937

# %%
blood_age_sex5 = blood_age_sex4.reset_index()

# %%
blood_age_sex6 = blood_age_sex5[blood_age_sex5['나이'].str.contains('20~')]
blood_age_sex6
# Out:
#    index      나이       남       여
# 1   2008  20~29세  789826  214132
# 7   2009  20~29세  837795  247998
# 13  2010  20~29세  778251  250331
# 19  2011  20~29세  709042  246747
# 25  2012  20~29세  757311  265924
# 31  2013  20~29세  856997  290320
# 37  2014  20~29세  915631  307597
# 43  2015  20~29세  926104  312194
# 49  2016  20~29세  826322  256074
# 55  2017  20~29세  834314  248519
# 61  2018  20~29세  809306  237017
# 67  2019  20~29세  729930  226017

# %%
blood_job8 = blood_job7.reset_index()
blood_job8
# Out:
#    index       계       남     여
# 0   2008  378552  377220  1332
# 1   2009  372983  371211  1772
# 2   2010  342455  340591  1864
# 3   2011  310272  308257  2015
# 4   2012  358640  356043  2597
# 5   2013  406560  403039  3521
# 6   2014  417257  413415  3842
# 7   2015  438359  434167  4192
# 8   2016  447225  443597  3628
# 9   2017  450868  447142  3726
# 10  2018  430820  426788  4032
# 11  2019  379748  374811  4937

# %%
df1 = pd.merge(blood_job8,blood_age_sex6, on='index')
df1.columns = ['year', '군인 계', '군인(남)', '군인(여)', '나이','남','여']
df1
# df1['20대 남자'] =df1['군인(남)'] - df1['남']
# df1['20대 여자'] =df1['군인(여)'] - df1['여']
# Out:
#     year    군인 계   군인(남) 군인(여)      나이       남       여
# 0   2008  378552  377220  1332  20~29세  789826  214132
# 1   2009  372983  371211  1772  20~29세  837795  247998
# 2   2010  342455  340591  1864  20~29세  778251  250331
# 3   2011  310272  308257  2015  20~29세  709042  246747
# 4   2012  358640  356043  2597  20~29세  757311  265924
# 5   2013  406560  403039  3521  20~29세  856997  290320
# 6   2014  417257  413415  3842  20~29세  915631  307597
# 7   2015  438359  434167  4192  20~29세  926104  312194
# 8   2016  447225  443597  3628  20~29세  826322  256074
# 9   2017  450868  447142  3726  20~29세  834314  248519
# 10  2018  430820  426788  4032  20~29세  809306  237017
# 11  2019  379748  374811  4937  20~29세  729930  226017

# %%
df1['군인 계'] = df1['군인 계'].astype(int)
df1['군인(남)'] = df1['군인(남)'].astype(int)
df1['군인(여)'] = df1['군인(여)'].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    12 non-null     object
#  1   군인 계    12 non-null     int32
#  2   군인(남)   12 non-null     int32
#  3   군인(여)   12 non-null     int32
#  4   나이      12 non-null     object
#  5   남       12 non-null     int32
#  6   여       12 non-null     int32
# dtypes: int32(5), object(2)
# memory usage: 528.0+ bytes

# %%
df1['20대 남자'] = df1['남'] - df1['군인(남)']
df1['20대 여자'] = df1['여'] - df1['군인(여)']
df1
df1
# Out:
#     year    군인 계   군인(남)  군인(여)      나이       남       여  20대 남자  20대 여자
# 0   2008  378552  377220   1332  20~29세  789826  214132  412606  212800
# 1   2009  372983  371211   1772  20~29세  837795  247998  466584  246226
# 2   2010  342455  340591   1864  20~29세  778251  250331  437660  248467
# 3   2011  310272  308257   2015  20~29세  709042  246747  400785  244732
# 4   2012  358640  356043   2597  20~29세  757311  265924  401268  263327
# 5   2013  406560  403039   3521  20~29세  856997  290320  453958  286799
# 6   2014  417257  413415   3842  20~29세  915631  307597  502216  303755
# 7   2015  438359  434167   4192  20~29세  926104  312194  491937  308002
# 8   2016  447225  443597   3628  20~29세  826322  256074  382725  252446
# 9   2017  450868  447142   3726  20~29세  834314  248519  387172  244793
# 10  2018  430820  426788   4032  20~29세  809306  237017  382518  232985
# 11  2019  379748  374811   4937  20~29세  729930  226017  355119  221080

# %%
plt.plot(df1['남'], label='남자')
plt.plot(df1['여'], label='여자')
plt.plot(df1['20대 남자'], label='군인제외 남자')
plt.plot(df1['20대 여자'], label='군인제외 여자')
plt.legend()
plt.title('20대 남녀 헌혈실적')
plt.show()

# %% [markdown]
# 군인을 제외해도 남자가 여자보다 2배가까운 수치를 보여주는 것을 알 수 있음

# %%
## 장소별
blood_place = pd.read_csv('blood data/장소별_헌혈통계_2005_2019 (2).csv', encoding = 'CP949', header=None)
blood_place
# Out:
#          0        1      2        3        4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계     단체헌혈     단체헌혈    단체헌혈     단체헌혈
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계    고등학교     고등학교
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  1209466     53.2  293838     12.9
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    17439     69.9    3405     13.6
# 57    대한적십자사       제주      여     6706     2647     39.5    1286     19.2
# 58  대한적십자사 외       소계      계    50700        0      0.0       0      0.0
# 59  대한적십자사 외       소계      남    42088        0      0.0       0      0.0
# 60  대한적십자사 외       소계      여     8612        0      0.0       0      0.0
#
#        8        9    ...     308      309      310      311     312      313  \
# ...

# %%
# 대한 적십자사 외의 데이터는 제거해준다
blood_place2 = blood_place.drop(index=[4,5,6,58,59,60])
blood_place2.T
# Out:
#           0        1        2        3        7        8       9       10  \
# 0    혈액원별(1)  혈액원별(1)  혈액원별(1)  혈액원별(1)   대한적십자사   대한적십자사  대한적십자사  대한적십자사
# 1    혈액원별(2)  혈액원별(2)  혈액원별(2)  혈액원별(2)       소계       소계      소계    서울중앙
# 2      성별(1)    성별(1)    성별(1)    성별(1)        계        남       여       계
# 3       2005       합계       소계   실적 (건)  2223636  1789525  434111  210606
# 4       2005     단체헌혈       소계   실적 (건)  1209466  1076221  133245  115114
# ..       ...      ...      ...      ...      ...      ...     ...     ...
# 313     2019     개인헌혈       원내  구성비 (%)      1.5      1.6     1.2     2.1
# 314     2019     개인헌혈     헌혈의집   실적 (건)  1723781  1210397  513384  195370
# 315     2019     개인헌혈     헌혈의집  구성비 (%)     65.9     63.4    72.9    77.8
# 316     2019     개인헌혈       가두   실적 (건)     2402     1812     590      21
# 317     2019     개인헌혈       가두  구성비 (%)      0.1      0.1     0.1     0.0
#
#          11      12  ...      48      49      50      51      52      53  \
# ...

# %%
# 단체 헌혈을 파악해보기위해 단체헌혈 데이터만 가져온다
blood_place3 = blood_place2.T[blood_place2.T[1].str.contains('혈액원|단체헌혈|성별')].drop(index=0)
# 불필요한 컬럼제거
blood_place3 = blood_place3.drop(columns=1)
blood_place4 = blood_place3.T[blood_place3.T[2].str.contains('성별|계')]
blood_place4.T
# Out:
#           0        2        3        7       10     13     16      19     22  \
# 1    혈액원별(2)  혈액원별(2)  혈액원별(2)       소계    서울중앙   서울서부   서울남부    서울동부     부산
# 2      성별(1)    성별(1)    성별(1)        계       계      계      계       계      계
# 4       2005       소계   실적 (건)  1209466  115114  55697  84994  110191  87102
# 5       2005       소계  구성비 (%)     54.4    54.7   41.7   47.0    56.4   40.9
# 6       2005     고등학교   실적 (건)   293838   20574  14614  13351   21805  21341
# ..       ...      ...      ...      ...     ...    ...    ...     ...    ...
# 305     2019      군부대  구성비 (%)     11.1    11.3      -   13.3     9.9    7.0
# 306     2019       종교   실적 (건)     8946     642      -    505    1030   2445
# 307     2019       종교  구성비 (%)      0.3     0.3      -    0.2     0.4    1.1
# 308     2019     일반단체   실적 (건)   145435    4518      -  11380    9810   8707
# 309     2019     일반단체  구성비 (%)      5.6     1.8      -    5.3     3.8    4.1
#
# ...

# %%
# 계만 표시되는 데이터 제거
blood_place5 = blood_place4.T.drop(index=2)
# 일단 2005년 데이터만 먼저 본다
blood_place6 = blood_place5[blood_place5[0].str.contains('혈액|2005')]
blood_place7 = blood_place6[blood_place6[3].str.contains('실적')]
blood_place7
# Out:
#       0     2       3        7       10     13     16      19     22      25  \
# 4   2005    소계  실적 (건)  1209466  115114  55697  84994  110191  87102  108194
# 6   2005  고등학교  실적 (건)   293838   20574  14614  13351   21805  21341   33076
# 8   2005   대학교  실적 (건)   101838    8258   1546   4546    8975   5502   12490
# 10  2005   군부대  실적 (건)   559150   68161  27230  50858   67728  33568   35494
# 12  2005    종교  실적 (건)    25834    3065   3238   3123    3397   1500    1557
# 14  2005  일반단체  실적 (건)   228806   15056   9069  13116    8286  25191   25577
#
#        28     31     34     37     40      43     46     49     52     55
# 4   62632  38205  70503  65194  42444  115206  66983  98420  68501  20086
# 6   31133  12898  16231   5106  13132   20940  22099  32353  10494   4691
# 8    1138   1271  11000   1544   9027    9167   8963  10022   6507   1882
# 10  19039   8786  16478  54716  13543   70648  24932  26205  35371   6393
# ...

# %%
blood_place7 = blood_place7.set_index([0,2]).drop(columns=3)
blood_place7
# Out:
#                 7       10     13     16      19     22      25     28     31  \
# 0    2
# 2005 소계    1209466  115114  55697  84994  110191  87102  108194  62632  38205
#      고등학교   293838   20574  14614  13351   21805  21341   33076  31133  12898
#      대학교    101838    8258   1546   4546    8975   5502   12490   1138   1271
#      군부대    559150   68161  27230  50858   67728  33568   35494  19039   8786
#      종교      25834    3065   3238   3123    3397   1500    1557   1412    471
#      일반단체   228806   15056   9069  13116    8286  25191   25577   9910  14779
#
#               34     37     40      43     46     49     52     55
# 0    2
# 2005 소계    70503  65194  42444  115206  66983  98420  68501  20086
#      고등학교  16231   5106  13132   20940  22099  32353  10494   4691
#      대학교   11000   1544   9027    9167   8963  10022   6507   1882
#      군부대   16478  54716  13543   70648  24932  26205  35371   6393
#      종교     1291    423    451    1077    824   2360   1307    338
# ...

# %%
blood_place7 = blood_place7.astype(int)
blood_place7[7].plot(kind='bar')
plt.show()

# %%
blood_place6 = blood_place5[[0,2,3,7]]
blood_place7 = blood_place6[blood_place6[3].str.contains('실적')]
blood_place8 = blood_place7.set_index(0).drop(columns=3)
blood_place8
# Out:
#          2        7
# 0
# 2005    소계  1209466
# 2005  고등학교   293838
# 2005   대학교   101838
# 2005   군부대   559150
# 2005    종교    25834
# ...    ...      ...
# 2019  고등학교   322619
# 2019   대학교    81802
# 2019   군부대   289426
# 2019    종교     8946
# 2019  일반단체   145435
#
# [90 rows x 2 columns]

# %%
blood_place8[7]= blood_place8[7].astype(int)
blood_place8
# Out:
#          2        7
# 0
# 2005    소계  1209466
# 2005  고등학교   293838
# 2005   대학교   101838
# 2005   군부대   559150
# 2005    종교    25834
# ...    ...      ...
# 2019  고등학교   322619
# 2019   대학교    81802
# 2019   군부대   289426
# 2019    종교     8946
# 2019  일반단체   145435
#
# [90 rows x 2 columns]

# %%
blood_place_re = blood_place8.reset_index()

# %%
drop_idx = blood_place_re[blood_place_re[0].str.contains('2005|2006|2007')].index

# %%
blood_place8 = blood_place_re.drop(index=drop_idx)
drop_idx2 = blood_place8[blood_place8[2].str.contains('소계')].index
blood_place8 = blood_place8.drop(index=drop_idx2)
blood_place9 = blood_place8.set_index([0,2], drop=True)
blood_place9.columns= ['헌혈 실적']
blood_place9
# Out:
#             헌혈 실적
# 0    2
# 2008 고등학교  337228
#      대학교    87216
#      군부대   336504
#      종교     10307
#      일반단체  194591
# 2009 고등학교  284924
#      대학교    87735
#      군부대   319614
#      종교      8150
#      일반단체  223485
# 2010 고등학교  355296
#      대학교    70804
#      군부대   283313
#      종교      4988
#      일반단체  169371
# 2011 고등학교  350917
#      대학교    68468
#      군부대   252473
#      종교      7139
#      일반단체  148703
# 2012 고등학교  354586
#      대학교    68447
#      군부대   298370
#      종교      9830
#      일반단체  149568
# 2013 고등학교  365062
#      대학교    76208
#      군부대   331664
#      종교      3018
#      일반단체  146835
# 2014 고등학교  362898
#      대학교    83155
#      군부대   332517
#      종교      7821
#      일반단체  142325
# 2015 고등학교  330823
#      대학교    85549
#      군부대   335482
#      종교      9680
#      일반단체  142223
# 2016 고등학교  352432
#      대학교    71240
#      군부대   347407
#      종교      9301
#      일반단체  137388
# 2017 고등학교  345367
#      대학교    74043
#      군부대   347109
# ...

# %%
blood_place9.plot(kind='bar')
plt.show()

# %% [markdown]
# ## 개인 헌혈과 단체 헌혈 매년 구성비 비교

# %%
blood_place = pd.read_csv('blood data/장소별_헌혈통계_2005_2019 (2).csv', encoding = 'CP949', header=None)
blood_place
# Out:
#          0        1      2        3        4        5       6        7    \
# 0    혈액원별(1)  혈액원별(2)  성별(1)     2005     2005     2005    2005     2005
# 1    혈액원별(1)  혈액원별(2)  성별(1)       합계     단체헌혈     단체헌혈    단체헌혈     단체헌혈
# 2    혈액원별(1)  혈액원별(2)  성별(1)       소계       소계       소계    고등학교     고등학교
# 3    혈액원별(1)  혈액원별(2)  성별(1)   실적 (건)   실적 (건)  구성비 (%)  실적 (건)  구성비 (%)
# 4         합계       소계      계  2274336  1209466     53.2  293838     12.9
# ..       ...      ...    ...      ...      ...      ...     ...      ...
# 56    대한적십자사       제주      남    24968    17439     69.9    3405     13.6
# 57    대한적십자사       제주      여     6706     2647     39.5    1286     19.2
# 58  대한적십자사 외       소계      계    50700        0      0.0       0      0.0
# 59  대한적십자사 외       소계      남    42088        0      0.0       0      0.0
# 60  대한적십자사 외       소계      여     8612        0      0.0       0      0.0
#
#        8        9    ...     308      309      310      311     312      313  \
# ...

# %%
dfblood_place.T[blood_place.T[1].str.contains('개인')]
# Out:
#        0     1     2        3        4        5       6        7        8   \
# 16   2005  개인헌혈    소계   실적 (건)  1064869   755392  309477  1014170   713304
# 17   2005  개인헌혈    소계  구성비 (%)     46.8     41.2    69.9     45.6     39.9
# 18   2005  개인헌혈    원내   실적 (건)    83779    69701   14078    33080    27613
# 19   2005  개인헌혈    원내  구성비 (%)      3.7      3.8     3.2      1.5      1.5
# 20   2005  개인헌혈  헌혈의집   실적 (건)   835073   577214  257859   835073   577214
# ..    ...   ...   ...      ...      ...      ...     ...      ...      ...
# 313  2019  개인헌혈    원내  구성비 (%)      1.5      1.6     1.3      1.5      1.6
# 314  2019  개인헌혈  헌혈의집   실적 (건)  1870399  1314974  555425  1723781  1210397
# 315  2019  개인헌혈  헌혈의집  구성비 (%)     67.0     64.6    73.6     65.9     63.4
# 316  2019  개인헌혈    가두   실적 (건)     5532     3988    1544     2402     1812
# 317  2019  개인헌혈    가두  구성비 (%)      0.2      0.2     0.2      0.1      0.1
#
# ...

# %%
df2 = df1[['year', '군인 계']].astype(int)
df2.set_index('year').plot()
plt.show()
